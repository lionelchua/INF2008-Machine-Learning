# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

BASE_URL = "https://sofifa.com/teams?hl=en-US"

# Headers to mimic a browser visit
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Target URLs for each roster date
EXTRA_TEAM_REQUESTS = {
    "FIFA 17": {
        "Aug 3, 2017": "https://sofifa.com/teams?type=all&lg%5B0%5D=13&r=170086&set=true&col=oa&sort=desc",  # All Premier League teams
        "Aug 10, 2017": "https://sofifa.com/teams?type=all&lg%5B0%5D=14&r=170087&set=true"  # Championship (filter: Newcastle, Brighton, Huddersfield)
    },
    "FIFA 19":{"Jul 18, 2019": "https://sofifa.com/teams?type=all&lg%5B0%5D=14&r=190072&set=true"},
    "FIFA 21": {
        "Aug 6, 2021": "https://sofifa.com/teams?type=all&lg%5B0%5D=14&r=210058&set=true"  # Championship (filter: Brentford, Nottingham Forest)
    },
    "FIFA 22": {
        "Aug 18, 2022": "https://sofifa.com/teams?type=all&lg%5B0%5D=14&r=220069&set=true"  # Championship (filter: Nottingham Forest)
    }
}

# Define team filters for specific dates
TEAM_FILTERS = {
    "FIFA 17": {
        "Aug 3, 2017": None,  # Keep all teams
        "Aug 10, 2017": ["Newcastle United", "Brighton & Hove Albion", "Huddersfield Town"]
    },
    "FIFA 19": {
        "Jul 18, 2019": ["Sheffield United", "Aston Villa", "Norwich City"]
    },
    "FIFA 21": {
        "Aug 6, 2021": ["Brentford", "Nottingham Forest"]
    },
    "FIFA 22": {
        "Aug 18, 2022": ["Nottingham Forest"]
    }
}

def get_versions_and_roster_dates():
    """Retrieve available FIFA versions (only FIFA18 - FC25) and corresponding roster update dates."""
    response = requests.get(BASE_URL, headers=HEADERS)
    if response.status_code != 200:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
        return None, None
    
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract FIFA versions and filter only FIFA18 - FC25
    version_select = soup.select_one('select[name="version"]')
    versions = {}

    if version_select:
        for option in version_select.find_all('option'):
            version_text = option.text.strip()
            version_value = option['value']
            
            # Ensure we only include FIFA18 to FC25
            valid_versions = ["FIFA 18", "FIFA 19", "FIFA 20", "FIFA 21", "FIFA 22", "FIFA 23", "FC 24", "FC 25"]
            if version_text in valid_versions:
                versions[version_text] = version_value
    
    print(f"Filtered FIFA versions: {versions}")

    # Extract roster dates for each version
    version_rosters = {}

    for version_name, version_value in versions.items():
        response = requests.get(f"{BASE_URL}&version={version_value}", headers=HEADERS)
        soup = BeautifulSoup(response.content, 'html.parser')

        roster_select = soup.select_one('select[name="roster"]')
        roster_dates = {}

        if roster_select:
            for option in roster_select.find_all('option'):
                roster_text = option.text.strip()
                roster_value = option['value']
                roster_dates[roster_text] = roster_value

        version_rosters[version_name] = roster_dates

    return versions, version_rosters

def scrape_premier_league_teams(version_name, version_value, roster_text, roster_value):
    """Scrape Premier League teams for a given FIFA version and roster date."""
    url = f"{BASE_URL}&version={version_value}&roster={roster_value}&lg[]=13"  # League ID 13 = Premier League
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code != 200:
        print(f"Failed to retrieve {url}. Status code: {response.status_code}")
        return None
    
    soup = BeautifulSoup(response.content, 'html.parser')
    team_rows = soup.select('tbody > tr')
    teams_data = []

    for row in team_rows:
        try:
            team_name_element = row.select_one('td.s20 > a')
            team_name = team_name_element.text.strip() if team_name_element else "N/A"
            team_url = team_name_element.get('href') if team_name_element else "N/A"
            team_id = team_url.split('/')[2] if team_url != "N/A" else "N/A"
            
            league_element = row.select_one('td.s20 a.sub')
            league = league_element.text.strip() if league_element else "N/A"
            
            overall = row.select_one('td[data-col="oa"]').text.strip() if row.select_one('td[data-col="oa"]') else "N/A"
            attack = row.select_one('td[data-col="at"]').text.strip() if row.select_one('td[data-col="at"]') else "N/A"
            midfield = row.select_one('td[data-col="md"]').text.strip() if row.select_one('td[data-col="md"]') else "N/A"
            defense = row.select_one('td[data-col="df"]').text.strip() if row.select_one('td[data-col="df"]') else "N/A"
            
            teams_data.append({
                'FIFA Version': version_name,
                'Roster Date': roster_text,  # Assign human-readable date
                'Team ID': team_id,
                'Team Name': team_name,
                'Team URL': f"https://sofifa.com{team_url}" if team_url != "N/A" else "N/A",
                'League': league,
                'Overall Rating': overall,
                'Attack': attack,
                'Midfield': midfield,
                'Defense': defense,
            })
            
        except Exception as e:
            print(f"Error processing team: {e}")

    return teams_data

def scrape_additional_teams(version_name, roster_text, url, filter_teams=None):
    """Scrape teams for a given FIFA version and roster date."""
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code != 200:
        print(f"Failed to retrieve {url}. Status code: {response.status_code}")
        return None
    
    soup = BeautifulSoup(response.content, 'html.parser')
    team_rows = soup.select('tbody > tr')
    teams_data = []

    for row in team_rows:
        try:
            team_name_element = row.select_one('td.s20 > a')
            team_name = team_name_element.text.strip() if team_name_element else "N/A"
            team_url = team_name_element.get('href') if team_name_element else "N/A"
            team_id = team_url.split('/')[2] if team_url != "N/A" else "N/A"
            
            league_element = row.select_one('td.s20 a.sub')
            league = league_element.text.strip() if league_element else "N/A"
            
            overall = row.select_one('td[data-col="oa"]').text.strip() if row.select_one('td[data-col="oa"]') else "N/A"
            attack = row.select_one('td[data-col="at"]').text.strip() if row.select_one('td[data-col="at"]') else "N/A"
            midfield = row.select_one('td[data-col="md"]').text.strip() if row.select_one('td[data-col="md"]') else "N/A"
            defense = row.select_one('td[data-col="df"]').text.strip() if row.select_one('td[data-col="df"]') else "N/A"
            
            teams_data.append({
                'FIFA Version': version_name,
                'Roster Date': roster_text,  # Assign human-readable date
                'Team ID': team_id,
                'Team Name': team_name,
                'Team URL': f"https://sofifa.com{team_url}" if team_url != "N/A" else "N/A",
                'League': league,
                'Overall Rating': overall,
                'Attack': attack,
                'Midfield': midfield,
                'Defense': defense,
            })
            
        except Exception as e:
            print(f"Error processing team: {e}")

    return teams_data

def filter_teams(df):
    """Filter the dataframe to keep only required rows."""
    filtered_data = []

    for version_name, version_filters in TEAM_FILTERS.items():
        for roster_text, allowed_teams in version_filters.items():
            # Convert text date to datetime for filtering
            roster_date = pd.to_datetime(roster_text, format='%b %d, %Y', errors='coerce')

            # Select rows matching the FIFA version and Roster Date
            subset = df[(df["FIFA Version"] == version_name) & (df["Roster Date"] == roster_date)]

            if allowed_teams is None:  # Keep all teams for this date
                filtered_data.append(subset)
            else:  # Keep only specific teams
                filtered_data.append(subset[subset["Team Name"].isin(allowed_teams)])

    return pd.concat(filtered_data, ignore_index=True) if filtered_data else df


def main():
    versions, version_rosters = get_versions_and_roster_dates()
    
    if not versions or not version_rosters:
        print("Failed to retrieve FIFA versions or roster dates.")
        return
    
    all_premier_league_data = []
    all_additional_team_data = []

    # Iterate through each FIFA version
    for version_name, version_value in versions.items():
        print(f"Scraping {version_name}...")

        # Get roster dates for this specific version
        roster_dates = version_rosters.get(version_name, {})

        print(f"Found {len(roster_dates)} roster dates for {version_name}")

        # Scrape data for each roster date
        for roster_text, roster_value in roster_dates.items():
            print(f"Scraping {version_name} - {roster_text} (Premier League)")
            team_data = scrape_premier_league_teams(version_name, version_value, roster_text, roster_value)
            
            if team_data:
                all_premier_league_data.extend(team_data)
            
            time.sleep(2)  # Avoid overwhelming the server


    # Scrape extra teams based on specific requests
    for version_name, details in EXTRA_TEAM_REQUESTS.items():
        for roster_text, url in details.items():
            print(f"Scraping {version_name} - {roster_text}")

            # Scrape data
            team_data = scrape_additional_teams(version_name, roster_text, url)
            if team_data:
                all_additional_team_data.extend(team_data)
            
            time.sleep(2)  # Avoid overwhelming the server

    # Convert to DataFrame
    premier_league_df = pd.DataFrame(all_premier_league_data)
    additional_team_df = pd.DataFrame(all_additional_team_data)

    # Convert Roster Date to proper date format
    premier_league_df['Roster Date'] = pd.to_datetime(premier_league_df['Roster Date'], format='%b %d, %Y', errors='coerce')
    additional_team_df['Roster Date'] = pd.to_datetime(additional_team_df['Roster Date'], format='%b %d, %Y', errors='coerce')

    # Apply filtering
    additional_team_df_filtered = filter_teams(additional_team_df)

    #Combine both DF together
    df = pd.concat([premier_league_df, additional_team_df_filtered], axis=0, ignore_index= True)

    # Sorting: Latest FIFA → Latest Date → Highest Overall Rating
    df.sort_values(by=["FIFA Version", "Roster Date", "Overall Rating"], ascending=[False, False, False], inplace=True)

    # Save to CSV
    df.to_csv('fifa_team_rating.csv', index=False)
    print("Data saved to 'fifa_team_rating.csv'")

if __name__ == "__main__":
    main()
# Out:
# Filtered FIFA versions: {'FC 25': '/teams?hl=en-US&r=250026&set=true', 'FC 24': '/teams?hl=en-US&r=240050&set=true', 'FIFA 23': '/teams?hl=en-US&r=230054&set=true', 'FIFA 22': '/teams?hl=en-US&r=220069&set=true', 'FIFA 21': '/teams?hl=en-US&r=210064&set=true', 'FIFA 20': '/teams?hl=en-US&r=200061&set=true', 'FIFA 19': '/teams?hl=en-US&r=190075&set=true', 'FIFA 18': '/teams?hl=en-US&r=180084&set=true'}
# Scraping FC 25...
# Found 25 roster dates for FC 25
# Scraping FC 25 - Mar 12, 2025 (Premier League)
# Scraping FC 25 - Mar 5, 2025 (Premier League)
# Scraping FC 25 - Feb 24, 2025 (Premier League)
# Scraping FC 25 - Feb 19, 2025 (Premier League)
# Scraping FC 25 - Feb 14, 2025 (Premier League)
# Scraping FC 25 - Feb 5, 2025 (Premier League)
# Scraping FC 25 - Feb 4, 2025 (Premier League)
# Scraping FC 25 - Jan 23, 2025 (Premier League)
# Scraping FC 25 - Jan 16, 2025 (Premier League)
# Scraping FC 25 - Jan 9, 2025 (Premier League)
# Scraping FC 25 - Dec 18, 2024 (Premier League)
# Scraping FC 25 - Dec 11, 2024 (Premier League)
# Scraping FC 25 - Dec 5, 2024 (Premier League)
# Scraping FC 25 - Nov 27, 2024 (Premier League)
# Scraping FC 25 - Nov 21, 2024 (Premier League)
# Scraping FC 25 - Nov 20, 2024 (Premier League)
# Scraping FC 25 - Nov 6, 2024 (Premier League)
# Scraping FC 25 - Nov 5, 2024 (Premier League)
# Scraping FC 25 - Oct 22, 2024 (Premier League)
# Scraping FC 25 - Oct 17, 2024 (Premier League)
# Scraping FC 25 - Oct 8, 2024 (Premier League)
# Scraping FC 25 - Oct 2, 2024 (Premier League)
# Scraping FC 25 - Sep 26, 2024 (Premier League)
# Scraping FC 25 - Sep 20, 2024 (Premier League)
# Scraping FC 25 - Aug 7, 2024 (Premier League)
# Scraping FC 24...
# Found 46 roster dates for FC 24
# Scraping FC 24 - Sep 4, 2024 (Premier League)
# Scraping FC 24 - Aug 20, 2024 (Premier League)
# Scraping FC 24 - Jul 24, 2024 (Premier League)
# Scraping FC 24 - Jul 8, 2024 (Premier League)
# Scraping FC 24 - Jul 4, 2024 (Premier League)
# Scraping FC 24 - Jun 26, 2024 (Premier League)
# Scraping FC 24 - Jun 12, 2024 (Premier League)
# Scraping FC 24 - Jun 11, 2024 (Premier League)
# Scraping FC 24 - May 22, 2024 (Premier League)
# Scraping FC 24 - May 8, 2024 (Premier League)
# Scraping FC 24 - May 7, 2024 (Premier League)
# Scraping FC 24 - Apr 23, 2024 (Premier League)
# Scraping FC 24 - Apr 9, 2024 (Premier League)
# Scraping FC 24 - Mar 27, 2024 (Premier League)
# Scraping FC 24 - Mar 20, 2024 (Premier League)
# Scraping FC 24 - Mar 14, 2024 (Premier League)
# Scraping FC 24 - Mar 7, 2024 (Premier League)
# Scraping FC 24 - Mar 6, 2024 (Premier League)
# Scraping FC 24 - Mar 5, 2024 (Premier League)
# Scraping FC 24 - Feb 22, 2024 (Premier League)
# Scraping FC 24 - Feb 15, 2024 (Premier League)
# Scraping FC 24 - Feb 8, 2024 (Premier League)
# Scraping FC 24 - Feb 1, 2024 (Premier League)
# Scraping FC 24 - Jan 31, 2024 (Premier League)
# Scraping FC 24 - Jan 30, 2024 (Premier League)
# Scraping FC 24 - Jan 17, 2024 (Premier League)
# Scraping FC 24 - Dec 18, 2023 (Premier League)
# Scraping FC 24 - Dec 11, 2023 (Premier League)
# Scraping FC 24 - Dec 6, 2023 (Premier League)
# Scraping FC 24 - Nov 24, 2023 (Premier League)
# Scraping FC 24 - Nov 20, 2023 (Premier League)
# Scraping FC 24 - Nov 15, 2023 (Premier League)
# Scraping FC 24 - Nov 9, 2023 (Premier League)
# Scraping FC 24 - Nov 1, 2023 (Premier League)
# Scraping FC 24 - Oct 30, 2023 (Premier League)
# Scraping FC 24 - Oct 26, 2023 (Premier League)
# Scraping FC 24 - Oct 23, 2023 (Premier League)
# Scraping FC 24 - Oct 16, 2023 (Premier League)
# Scraping FC 24 - Oct 12, 2023 (Premier League)
# Scraping FC 24 - Oct 10, 2023 (Premier League)
# Scraping FC 24 - Oct 5, 2023 (Premier League)
# Scraping FIFA 21 - Mar 30, 2021 (Premier League)
# Scraping FIFA 21 - Mar 26, 2021 (Premier League)
# Scraping FIFA 21 - Mar 19, 2021 (Premier League)
# Scraping FIFA 21 - Mar 12, 2021 (Premier League)
# Scraping FIFA 21 - Mar 10, 2021 (Premier League)
# Scraping FIFA 21 - Mar 6, 2021 (Premier League)
# Scraping FIFA 21 - Mar 4, 2021 (Premier League)
# Scraping FIFA 21 - Feb 19, 2021 (Premier League)
# Scraping FIFA 21 - Feb 18, 2021 (Premier League)
# Scraping FIFA 21 - Feb 5, 2021 (Premier League)
# Scraping FIFA 21 - Jan 29, 2021 (Premier League)
# Scraping FIFA 21 - Jan 26, 2021 (Premier League)
# Scraping FIFA 21 - Jan 22, 2021 (Premier League)
# Scraping FIFA 21 - Jan 19, 2021 (Premier League)
# Scraping FIFA 21 - Jan 15, 2021 (Premier League)
# Scraping FIFA 21 - Jan 11, 2021 (Premier League)
# Scraping FIFA 21 - Jan 6, 2021 (Premier League)
# Scraping FIFA 21 - Dec 11, 2020 (Premier League)
# Scraping FIFA 21 - Dec 10, 2020 (Premier League)
# Scraping FIFA 21 - Dec 4, 2020 (Premier League)
# Scraping FIFA 21 - Nov 28, 2020 (Premier League)
# Scraping FIFA 21 - Nov 27, 2020 (Premier League)
# Scraping FIFA 21 - Nov 20, 2020 (Premier League)
# Scraping FIFA 21 - Nov 17, 2020 (Premier League)
# Scraping FIFA 21 - Nov 13, 2020 (Premier League)
# Scraping FIFA 21 - Nov 6, 2020 (Premier League)
# Scraping FIFA 21 - Nov 4, 2020 (Premier League)
# Scraping FIFA 21 - Oct 29, 2020 (Premier League)
# Scraping FIFA 21 - Oct 27, 2020 (Premier League)
# Scraping FIFA 21 - Oct 16, 2020 (Premier League)
# Scraping FIFA 21 - Oct 9, 2020 (Premier League)
# Scraping FIFA 21 - Oct 5, 2020 (Premier League)
# Scraping FIFA 21 - Oct 1, 2020 (Premier League)
# Scraping FIFA 21 - Sep 23, 2020 (Premier League)
# Scraping FIFA 21 - Aug 24, 2020 (Premier League)
# Scraping FIFA 20...
# Found 60 roster dates for FIFA 20
# Scraping FIFA 20 - Sep 23, 2020 (Premier League)
# Scraping FIFA 20 - Sep 17, 2020 (Premier League)
# Scraping FIFA 20 - Sep 10, 2020 (Premier League)
# Scraping FIFA 20 - Sep 2, 2020 (Premier League)
# Scraping FIFA 20 - Aug 20, 2020 (Premier League)
# Scraping FIFA 20 - Aug 12, 2020 (Premier League)
# Scraping FIFA 20 - Aug 6, 2020 (Premier League)
# Scraping FIFA 20 - Jul 30, 2020 (Premier League)
# Scraping FIFA 20 - Jul 23, 2020 (Premier League)
# Scraping FIFA 20 - Jul 16, 2020 (Premier League)
# Scraping FIFA 20 - Jul 8, 2020 (Premier League)
# Scraping FIFA 20 - Jul 2, 2020 (Premier League)
# Scraping FIFA 20 - Jun 24, 2020 (Premier League)
# Scraping FIFA 20 - Jun 17, 2020 (Premier League)
# Scraping FIFA 20 - Jun 11, 2020 (Premier League)
# Scraping FIFA 20 - Jun 9, 2020 (Premier League)
# Scraping FIFA 20 - Jun 3, 2020 (Premier League)
# Scraping FIFA 20 - May 27, 2020 (Premier League)
# Scraping FIFA 20 - May 20, 2020 (Premier League)
# Scraping FIFA 20 - May 19, 2020 (Premier League)
# Scraping FIFA 20 - May 14, 2020 (Premier League)
# Scraping FIFA 20 - May 6, 2020 (Premier League)
# Scraping FIFA 20 - Apr 29, 2020 (Premier League)
# Scraping FIFA 20 - Apr 28, 2020 (Premier League)
# Scraping FIFA 20 - Apr 22, 2020 (Premier League)
# Scraping FIFA 20 - Apr 15, 2020 (Premier League)
# Scraping FIFA 20 - Apr 10, 2020 (Premier League)
# Scraping FIFA 20 - Apr 7, 2020 (Premier League)
# Scraping FIFA 20 - Apr 2, 2020 (Premier League)
# Scraping FIFA 20 - Mar 31, 2020 (Premier League)
# Scraping FIFA 20 - Mar 20, 2020 (Premier League)
# Scraping FIFA 20 - Mar 10, 2020 (Premier League)
# Scraping FIFA 20 - Mar 3, 2020 (Premier League)
# Scraping FIFA 20 - Feb 24, 2020 (Premier League)
# Scraping FIFA 20 - Feb 13, 2020 (Premier League)
# Scraping FIFA 20 - Feb 7, 2020 (Premier League)
# Scraping FIFA 20 - Feb 1, 2020 (Premier League)
# Scraping FIFA 20 - Jan 24, 2020 (Premier League)
# Scraping FIFA 20 - Jan 22, 2020 (Premier League)
# Scraping FIFA 20 - Jan 10, 2020 (Premier League)
# Scraping FIFA 20 - Jan 6, 2020 (Premier League)
# Scraping FIFA 20 - Jan 2, 2020 (Premier League)
# Scraping FIFA 20 - Dec 24, 2019 (Premier League)
# Scraping FIFA 20 - Dec 18, 2019 (Premier League)
# Scraping FIFA 20 - Dec 14, 2019 (Premier League)
# Scraping FIFA 20 - Dec 11, 2019 (Premier League)
# Scraping FIFA 20 - Dec 6, 2019 (Premier League)
# Scraping FIFA 20 - Dec 4, 2019 (Premier League)
# Scraping FIFA 20 - Nov 22, 2019 (Premier League)
# Scraping FIFA 20 - Nov 19, 2019 (Premier League)
# Scraping FIFA 20 - Nov 13, 2019 (Premier League)
# Scraping FIFA 20 - Nov 6, 2019 (Premier League)
# Scraping FIFA 20 - Oct 29, 2019 (Premier League)
# Scraping FIFA 20 - Oct 16, 2019 (Premier League)
# Scraping FIFA 20 - Oct 4, 2019 (Premier League)
# Scraping FIFA 20 - Oct 1, 2019 (Premier League)
# Scraping FIFA 20 - Sep 27, 2019 (Premier League)
# Scraping FIFA 20 - Sep 26, 2019 (Premier League)
# Scraping FIFA 20 - Sep 19, 2019 (Premier League)
# Scraping FIFA 20 - Aug 20, 2019 (Premier League)
# Scraping FIFA 19...
# Found 75 roster dates for FIFA 19
# Scraping FIFA 19 - Sep 11, 2019 (Premier League)
# Scraping FIFA 19 - Aug 29, 2019 (Premier League)
# Scraping FIFA 19 - Aug 15, 2019 (Premier League)
# Scraping FIFA 19 - Jul 18, 2019 (Premier League)
# Scraping FIFA 19 - Jul 11, 2019 (Premier League)
# Scraping FIFA 19 - Jul 4, 2019 (Premier League)
# Scraping FIFA 19 - Jun 27, 2019 (Premier League)
